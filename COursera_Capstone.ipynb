# %% [markdown]
# <h1 align='center'><font size=10 family ='Times New Roman'>Applied Data Science Capstone</font></h1>

# %% [markdown]
# ## By Gaurav Bhardwaj

# %% [markdown]
# This Notebook is made for final course of `Professional Course Certificate` provided by `IBM` on `Coursera`.

# %% [markdown]
# Importing Modules

# %%
import pandas as pd
import numpy as np
print("--------- Importing Done ----------")
print('\n Hello Capstone Project Course')
# Out:
# --------- Importing Done ----------
#
#  Hello Capstone Project Course

# %% [markdown]
# <h2 align ='center'>Thank You</h2>
